# %%
import pandas as pd

# %%
path = '/Users/jjmilla/Downloads/NACE_Rev2_Structure.csv'

df_nace_des = pd.read_csv(path, sep=',')

print(f'Shape of the extracted df_nace_des data: {df_nace_des.shape}')
print(f'Number of unique NACEs: {df_nace_des.ID.nunique()}')
display(df_nace_des.head(10))
# Out:
# Shape of the extracted df_nace_des data: (996, 9)
# Number of unique NACEs: 996
#    ORDER_KEY    ID   CODE                                               NAME  \
# 0        200     A      A                  AGRICULTURE, FORESTRY AND FISHING
# 1        300    01     01  Crop and animal production, hunting and relate...
# 2        350   011   01.1                     Growing of non-perennial crops
# 3        355  0111  01.11  Growing of cereals (except rice), leguminous c...
# 4        360  0112  01.12                                    Growing of rice
# 5        365  0113  01.13  Growing of vegetables and melons, roots and tu...
# 6        370  0114  01.14                              Growing of sugar cane
# 7        375  0115  01.15                                 Growing of tobacco
# 8        380  0116  01.16                             Growing of fibre crops
# 9        385  0119  01.19               Growing of other non-perennial crops
#
# ...

# %%
df_nace_des[df_nace_des.PARENT_ID.isnull()]
# Out:
#      ORDER_KEY ID CODE                                               NAME  \
# 0          200  A    A                  AGRICULTURE, FORESTRY AND FISHING
# 56        1945  B    B                               MINING AND QUARRYING
# 87        3220  C    C                                      MANUFACTURING
# 437      15650  D    D  ELECTRICITY, GAS, STEAM AND AIR CONDITIONING S...
# 450      16260  E    E  WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND R...
# 470      17650  F    F                                       CONSTRUCTION
# 505      21175  G    G  WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VE...
# 621      25630  H    H                         TRANSPORTATION AND STORAGE
# 665      28260  I    I          ACCOMMODATION AND FOOD SERVICE ACTIVITIES
# 683      29055  J    J                      INFORMATION AND COMMUNICATION
# 729      31725  K    K                 FINANCIAL AND INSURANCE ACTIVITIES
# 761      32940  L    L                             REAL ESTATE ACTIVITIES
# ...

# %%
df_nace_des[df_nace_des.PARENT_ID == 'L']
# Out:
#      ORDER_KEY  ID CODE                    NAME PARENT_ID  LEVEL Includes  \
# 762      33240  68   68  Real estate activities         L      2      NaN
#
#     IncludesAlso Excludes
# 762          NaN      NaN

# %%
df_nace_des[df_nace_des.PARENT_ID == '68']
# Out:
#      ORDER_KEY   ID  CODE                                               NAME  \
# 763      33390  681  68.1              Buying and selling of own real estate
# 765      33445  682  68.2  Renting and operating of own or leased real es...
# 767      33555  683  68.3  Real estate activities on a fee or contract basis
#
#     PARENT_ID  LEVEL Includes IncludesAlso Excludes
# 763        68      3      NaN          NaN      NaN
# 765        68      3      NaN          NaN      NaN
# 767        68      3      NaN          NaN      NaN

# %%
df_nace_des[df_nace_des.PARENT_ID == '681']
# Out:
#      ORDER_KEY    ID   CODE                                   NAME PARENT_ID  \
# 764      33395  6810  68.10  Buying and selling of own real estate       681
#
#      LEVEL                                           Includes  \
# 764      4  This class includes:\n- buying and selling of ...
#
#                                           IncludesAlso  \
# 764  This class also includes\n- subdividing real e...
#
#                                               Excludes
# 764  This class excludes:\n- development of buildin...

# %%
df_nace_des[df_nace_des.ID == '1072']
# Out:
#      ORDER_KEY    ID   CODE  \
# 110       4145  1072  10.72
#
#                                                   NAME PARENT_ID  LEVEL  \
# 110  Manufacture of rusks and biscuits; manufacture...       107      4
#
#                                               Includes IncludesAlso  \
# 110  This class includes:\n- manufacture of rusks, ...          NaN
#
#                                               Excludes
# 110  This class excludes:\n- manufacture of potato ...

# %%
df_nace_des[df_nace_des.ID == '1071']
# Out:
#      ORDER_KEY    ID   CODE  \
# 109       4140  1071  10.71
#
#                                                   NAME PARENT_ID  LEVEL  \
# 109  Manufacture of bread; manufacture of fresh pas...       107      4
#
#                                               Includes IncludesAlso  \
# 109  This class includes:\n- manufacture of bakery ...          NaN
#
#                                               Excludes
# 109  This class excludes:\n- manufacture of dry bak...

# %%
df_nace_des[df_nace_des.PARENT_ID == '322']
# Out:
#      ORDER_KEY    ID   CODE                                NAME PARENT_ID  \
# 415      14490  3220  32.20  Manufacture of musical instruments       322
#
#      LEVEL                                           Includes  \
# 415      4  This class includes:\n- manufacture of stringe...
#
#                                           IncludesAlso  \
# 415  This class also includes:\n- manufacture of wh...
#
#                                               Excludes
# 415  This class excludes:\n- reproduction of pre-re...
